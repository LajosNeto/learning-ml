# %% [markdown]
# # Detect Overfitting and Underfitting with Learning Curves

# %% [markdown]
# In this notebook a visual approach for detecting overfitting and underfitting is implemented.
#
# <br>
#
# The following models are used :
# * Decision Tree model
# * Logistic Regression model
# * Support Vector Machine model
#
# <br>
#
# Curves reference :
# ![Screen%20Shot%202019-06-02%20at%2011.57.59.png](attachment:Screen%20Shot%202019-06-02%20at%2011.57.59.png)
